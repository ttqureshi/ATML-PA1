# %% [markdown]
# # Task 1: Inductive Biases and Feature Representations

# %%
import torch

print("cuda:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("device:", torch.cuda.get_device_name(0))
# Out:
# cuda: True
# device: Tesla T4

# %%
from google.colab import drive
from pathlib import Path
import os

drive.mount("/content/drive")

REPO_DIR = Path("/content/drive/MyDrive/MS AI/Semester_3/ATML/PAs/ATML-PA1")
os.chdir(REPO_DIR)
print("cwd:", Path.cwd())
# Out:
# Mounted at /content/drive
# cwd: /content/drive/MyDrive/MS AI/Semester_3/ATML/PAs/ATML-PA1

# %%
# !pip -q install open-clip-torch PyYAML scikit-learn matplotlib tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.4 MB/s eta 0:00:00

# %%
# !python -m task1.scripts.run_task1 --config task1/configs/default.yaml
# Out:
# ===== STAGE: splits =====
# 100% 2.64G/2.64G [01:24<00:00, 31.1MB/s]
# Wrote task1/results/splits/train_val_split.json
#   train=4000 val=1000
# Wrote task1/results/splits/eval_subset.json
#   eval_subset=500 counts={'airplane': 50, 'bird': 50, 'car': 50, 'cat': 50, 'deer': 50, 'dog': 50, 'horse': 50, 'monkey': 50, 'ship': 50, 'truck': 50}
#
# ===== STAGE: train linear heads =====
# Device: cuda
#
# === Training linear head for resnet50 ===
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 141MB/s]
#   Extracting train features...
#   Extracting val features...
#   epoch 01  loss=1.1125  val_acc=0.9610  val_f1=0.9612
#   epoch 02  loss=0.3114  val_acc=0.9650  val_f1=0.9651
#   epoch 03  loss=0.1719  val_acc=0.9700  val_f1=0.9701
#   epoch 04  loss=0.1174  val_acc=0.9710  val_f1=0.9710
#   epoch 05  loss=0.0884  val_acc=0.9730  val_f1=0.9731
# ...

# %%
import json
from pathlib import Path

summary_path = Path("task1/results/tables/task1_summary.json")
with open(summary_path, encoding="utf-8") as f:
    summary = json.load(f)

print("Assumptions:")
for k, v in summary["assumptions"].items():
    print(f"  {k}: {v}")

print("\nClean baseline:")
for model, metrics in summary["clean"]["metrics"].items():
    print(
        f"  {model}: acc={metrics['top1_accuracy']:.4f}, "
        f"macro-F1={metrics['macro_f1']:.4f}, "
        f"mean_max_conf={metrics['mean_max_confidence']:.4f}"
    )
# Out:
# Assumptions:
#   dataset: STL-10
#   seed: 6304
#   extra_color_intervention: hue_rotate
#   hue_degrees: 90.0
#   cue_conflict_method: AdaIN
#   style_alpha: 1.0
#   class_pairs: [['airplane', 'bird'], ['car', 'truck'], ['cat', 'dog'], ['deer', 'horse'], ['ship', 'monkey']]
#   representation_viz: tsne
#
# Clean baseline:
#   resnet50: acc=0.9780, macro-F1=0.9780, mean_max_conf=0.9651
#   vit_b_16: acc=0.9760, macro-F1=0.9759, mean_max_conf=0.9637
#   clip_vit_b_32: acc=0.9820, macro-F1=0.9820, mean_max_conf=0.3347
#   clip_zeroshot: acc=0.9680, macro-F1=0.9675, mean_max_conf=0.9427
